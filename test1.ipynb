# %%
import pandas as pd
import numpy as np
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.special import inv_boxcox

import re

# %%
fifa_data = pd.read_csv('fifa21_male2.csv')
fifa_data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP',
#        'Position', 'Player Photo',
#        ...
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'Gender'],
#       dtype='object', length=107)

# %% [markdown]
# ## 1. choosing the columns we want

# %%
data = fifa_data[['ID', 'Name', 'Age', 'OVA', 'POT', 'Growth', 'BOV', 'Total Stats', 'Base Stats', 'A/W', 'D/W', 'Aggression', 'Interceptions', 'Composure', 'Penalties', 'Mentality', 'Positioning', 'Vision', 'IR', 'Value', 'Wage', 'Release Clause']]
data
# Out:
#            ID             Name  Age  OVA  POT  Growth  BOV  Total Stats  \
# 0           2      G. Pasquale   33   69   69       0   71         1929
# 1          16      Luis García   37   71   71       0   70         1906
# 2          27          J. Cole   33   71   71       0   71         1770
# 3          36         D. Yorke   36   68   82      14   70         1348
# 4          41          Iniesta   36   81   81       0   82         2014
# ...       ...              ...  ...  ...  ...     ...  ...          ...
# 17120  259088       A. Medioub   22   64   69       5   66         1367
# 17121  259090       W. Rickard   18   56   66      10   58         1529
# 17122  259091       C. Barrett   18   56   67      11   56         1430
# 17123  259101   J. Gazibegović   20   62   73      11   62         1579
# 17124  259105  Pablo Rodríguez   18   59   74      15   61         1401
#
#        Base Stats     A/W  ... Interceptions  Composure  Penalties  Mentality  \
# 0             408  Medium  ...          69.0        NaN         50        320
# 1             385  Medium  ...          71.0       79.0         75        362
# 2             354  Medium  ...          39.0        NaN         66        317
# 3             369     NaN  ...          70.0        NaN         70        271
# 4             420    High  ...          70.0       89.0         71        370
# ...           ...     ...  ...           ...        ...        ...        ...
# 17120         302  Medium  ...          58.0       46.0         39        218
# 17121         319  Medium  ...          50.0       46.0         50        259
# 17122         303  Medium  ...          55.0       43.0         49        256
# 17123         335    High  ...          58.0       54.0         36        257
# 17124         295    High  ...          11.0       57.0         67        224
#
#        Positioning  Vision   IR  Value  Wage Release Clause
# 0             63.0    66.0  2 ★  €625K   €7K             €0
# 1             72.0    73.0  1 ★  €600K   €7K          €1.1M
# 2             69.0    74.0  2 ★  €1.1M  €15K             €0
# 3             72.0     NaN  1 ★     €0    €0             €0
# 4             78.0    93.0  4 ★  €5.5M  €12K          €7.2M
# ...            ...     ...  ...    ...   ...            ...
# 17120         23.0    29.0  1 ★  €550K   €2K             €0
# 17121         55.0    53.0  1 ★  €130K   €3K          €273K
# 17122         49.0    45.0  1 ★  €130K   €2K          €273K
# 17123         46.0    56.0  1 ★  €475K   €3K          €784K
# 17124         64.0    50.0  1 ★  €325K   €2K          €788K
#
# [17125 rows x 22 columns]

# %%
#fifa1 = fifa_data['Name']
#fifa2 = fifa_data['A/W']
#fifa3 = fifa_data['D/W']
#fifa4 = fifa_data['Defending']
#fifa5 = fifa_data['Attacking']

#data = pd.concat([fifa1, fifa2, fifa3, fifa4, fifa5], join = 'inner', axis = 1)
#data

# %% [markdown]
# # Standardizing

# %%
def cleaning_0(data): 
    cols = [col_name.lower().replace(' ', '_') for col_name in data.columns]
    data.columns = cols
    question1 = input("Are there columns to drop? (Y/N)")
    while question1 == "Y":
        which_one = input("Enter column to drop (None: script runs further):")
        if which_one != "None":
            data = data.drop([which_one], axis=1)
            question2 = input("Are there more columns to drop? (Y/N)")
            if question2 == "Y":
                question1 = question2
            elif question2 == "N":
                print("No more columns dropped.")
                break
            else:
                print("Error: input must be Y or N!")
                question2 = input("Are there more columns to drop? (Y/N)")   
        elif which_one == "None":
            break   
    if question1 == "N":
        print("No columns dropped.")
    elif question1 != "Y" and question1 != "N":
        print("Error: input must be Y or N!")
        question1 = input("Are there columns to drop? (Y/N)")
        while question1 == "Y":
            which_one = input("Enter column to drop (None: continue without dropping or random key: repeat question):")
            if which_one == "None":
                break
            elif which_one != "None":
                data = data.drop([which_one], axis=1)
                question2 = input("Are there more columns to drop? (Y/N)")
                if question2 == "Y":
                    question1 = question2
                elif question2 == "N":
                    print("No more columns dropped.")
                    break
                else:
                    print("Error: input must be Y or N!")
                    question2 = input("Are there more columns to drop? (Y/N)")
        if question1 == "N":
            print("No columns dropped.")
        elif question1 != "Y" and question1 != "N":
            ("Error: input must be Y or N! To drop columns re-run function. Standardisation nevertheless complete")
            question1 = input("Are there columns to drop? (Y/N)")
    return data

# %%
cleaning_0(data)        # I removed the command for alphabetical order from my function, because it was harder to read the data with it
# Out:
# No columns dropped.
#            id             name  age  ova  pot  growth  bov  total_stats  \
# 0           2      G. Pasquale   33   69   69       0   71         1929
# 1          16      Luis García   37   71   71       0   70         1906
# 2          27          J. Cole   33   71   71       0   71         1770
# 3          36         D. Yorke   36   68   82      14   70         1348
# 4          41          Iniesta   36   81   81       0   82         2014
# ...       ...              ...  ...  ...  ...     ...  ...          ...
# 17120  259088       A. Medioub   22   64   69       5   66         1367
# 17121  259090       W. Rickard   18   56   66      10   58         1529
# 17122  259091       C. Barrett   18   56   67      11   56         1430
# 17123  259101   J. Gazibegović   20   62   73      11   62         1579
# 17124  259105  Pablo Rodríguez   18   59   74      15   61         1401
#
#        base_stats     a/w  ... interceptions  composure  penalties  mentality  \
# 0             408  Medium  ...          69.0        NaN         50        320
# 1             385  Medium  ...          71.0       79.0         75        362
# 2             354  Medium  ...          39.0        NaN         66        317
# 3             369     NaN  ...          70.0        NaN         70        271
# 4             420    High  ...          70.0       89.0         71        370
# ...           ...     ...  ...           ...        ...        ...        ...
# 17120         302  Medium  ...          58.0       46.0         39        218
# 17121         319  Medium  ...          50.0       46.0         50        259
# 17122         303  Medium  ...          55.0       43.0         49        256
# 17123         335    High  ...          58.0       54.0         36        257
# 17124         295    High  ...          11.0       57.0         67        224
#
#        positioning  vision   ir  value  wage release_clause
# 0             63.0    66.0  2 ★  €625K   €7K             €0
# 1             72.0    73.0  1 ★  €600K   €7K          €1.1M
# 2             69.0    74.0  2 ★  €1.1M  €15K             €0
# 3             72.0     NaN  1 ★     €0    €0             €0
# 4             78.0    93.0  4 ★  €5.5M  €12K          €7.2M
# ...            ...     ...  ...    ...   ...            ...
# 17120         23.0    29.0  1 ★  €550K   €2K             €0
# 17121         55.0    53.0  1 ★  €130K   €3K          €273K
# 17122         49.0    45.0  1 ★  €130K   €2K          €273K
# 17123         46.0    56.0  1 ★  €475K   €3K          €784K
# 17124         64.0    50.0  1 ★  €325K   €2K          €788K
#
# [17125 rows x 22 columns]

# %%
data1 = data.copy()

# %%
data1['value'] = data1['value'].str.replace('€', '')

# %%
data1['value'] = data1['value'].str.replace('K', '000').apply(lambda x : int(x) * 1000) ## NOT SPECIFIC TO OUR VALUES OF INTEREST
data1

# %%
data['value'] = data['value'].apply(lambda x: int(x))

# %% [markdown]
# ## Dealing with Null values

# %%
data.isnull().sum()
# Out:
# id                  0
# name                0
# age                 0
# ova                 0
# pot                 0
# growth              0
# bov                 0
# total_stats         0
# base_stats          0
# a/w                89
# d/w                89
# aggression          0
# interceptions       7
# composure         423
# penalties           0
# mentality           0
# positioning         7
# vision             58
# ir                  0
# value               0
# wage                0
# release_clause      0
# dtype: int64

# %%
# a df with all the rows containing nans in a specific column, in case we want to examine 

nan_frame = data.loc[data['composure'].isna()]
nan_frame
# Out:
#           id          name  age  ova  pot  growth  bov  total_stats  \
# 0          2   G. Pasquale   33   69   69       0   71         1929
# 2         27       J. Cole   33   71   71       0   71         1770
# 3         36      D. Yorke   36   68   82      14   70         1348
# 5         61    D. Odonkor   27   66   70       4   66         1649
# 7        241      R. Giggs   39   78   78       0   78         1939
# ...      ...           ...  ...  ...  ...     ...  ...          ...
# 8795  229902   S. Lochhead   18   56   72      16   56         1476
# 8813  229952        Rômulo   20   68   75       7   68         1662
# 9290  231577    O. Morales   27   59   59       0   60         1410
# 9702  233277  M. Mayrovich   19   60   71      11   60         1423
# 9918  234179   A. Alfageme   24   65   67       2   65         1683
#
#       base_stats     a/w  ... interceptions  composure  penalties  mentality  \
# 0            408  Medium  ...          69.0        NaN         50        320
# 2            354  Medium  ...          39.0        NaN         66        317
# 3            369     NaN  ...          70.0        NaN         70        271
# 5            360  Medium  ...          26.0        NaN         46        256
# 7            392  Medium  ...          47.0        NaN         90        358
# ...          ...     ...  ...           ...        ...        ...        ...
# 8795         317  Medium  ...          28.0        NaN         44        212
# 8813         352  Medium  ...          18.0        NaN         65        258
# 9290         310  Medium  ...          60.0        NaN         42        223
# 9702         309  Medium  ...          12.0        NaN         66        217
# 9918         366  Medium  ...          64.0        NaN         48        282
#
#       positioning  vision   ir  value  wage release_clause
# 0            63.0    66.0  2 ★  €625K   €7K             €0
# 2            69.0    74.0  2 ★  €1.1M  €15K             €0
# 3            72.0     NaN  1 ★     €0    €0             €0
# 5            63.0    58.0  2 ★  €725K   €5K             €0
# 7            78.0    83.0  3 ★    €1K  €60K             €0
# ...           ...     ...  ...    ...   ...            ...
# 8795         46.0    54.0  1 ★  €200K   €2K             €0
# 8813         65.0    66.0  1 ★  €1.2M   €8K             €0
# 9290         37.0    37.0  1 ★     €0    €0             €0
# 9702         57.0    54.0  1 ★  €300K   €2K             €0
# 9918         50.0    52.0  1 ★     €0    €0             €0
#
# [423 rows x 22 columns]

# %%
#data1 = data.dropna(how='any',axis=0) 
#data1

# %%
data1.isnull().sum()
# Out:
# name         0
# a/w          0
# d/w          0
# defending    0
# attacking    0
# dtype: int64

# %% [markdown]
# # begin exploring
