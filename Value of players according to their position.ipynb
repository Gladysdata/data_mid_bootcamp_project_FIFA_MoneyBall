# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os
import math

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv(r"C:\Users\Gladys\Desktop\FIFA\Cleaned_data.csv")
df = data.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)
df
# Out:
#            id             name  age  ova          nationality           club  \
# 0           2      G. Pasquale   33   69                Italy        Udinese
# 1          16      Luis García   37   71                Spain      KAS Eupen
# 2          27          J. Cole   33   71              England  Coventry City
# 3          36         D. Yorke   36   68  Trinidad and Tobago     Sunderland
# 4          41          Iniesta   36   81                Spain    Vissel Kobe
# ...       ...              ...  ...  ...                  ...            ...
# 17120  259088       A. Medioub   22   64               France     CD Tondela
# 17121  259090       W. Rickard   18   56                Wales        Burnley
# 17122  259091       C. Barrett   18   56              England        Burnley
# 17123  259101   J. Gazibegović   20   62   Bosnia Herzegovina  SK Sturm Graz
# 17124  259105  Pablo Rodríguez   18   59                Spain          Lecce
#
# ...

# %% [markdown]
# ***
#
# Value of players according to their position
#
# ***

# %%
df2 = df[['name', 'age', 'bp', 'value']]
df2
# Out:
#                   name  age   bp    value
# 0          G. Pasquale   33  LWB   625000
# 1          Luis García   37   CM   600000
# 2              J. Cole   33  CAM  1100000
# 3             D. Yorke   36   ST        0
# 4              Iniesta   36  CAM  5500000
# ...                ...  ...  ...      ...
# 17120       A. Medioub   22   CB   550000
# 17121       W. Rickard   18  CAM   130000
# 17122       C. Barrett   18   RB   130000
# 17123   J. Gazibegović   20   RB   475000
# 17124  Pablo Rodríguez   18   ST   325000
#
# [17125 rows x 4 columns]

# %%
plt.ticklabel_format(style='plain')
sns.barplot(x = 'bp',y = 'value',data = df2)
plt.show()
